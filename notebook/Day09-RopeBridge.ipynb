# %% [markdown]
# # Advent of code Day 9 - Rope Bridge
#
# ### rules
# * tail must move next to head every step that separates them
# * special cases of note:
#     * diagonal is considered touching, so a move by H which results in T not sharing the same row and column but only 1 away is fine
#     * any separation of HT while not int he same row and col that is beyond 1 T moves diagonally to close hte gap
#     * allow overlaps
#
# ## Part 1 - Number of unique points T has visited
# - include start point
# - play H moves one at a time
# - moves are defined as
#     - left  ( 0,-1)
#     - right ( 0, 1)
#     - up    ( 1, 0)
#     - down  (-1, 0)
#
# ```
# aahgg
# a...g
# b.T.f
# c...e
# ccdee
# ```
# - if H moves within the coords of T or its neighbors ( the dots or T)
#     - T does nothing
# - if H moves the ring outside the neighbors T must act ( the letters )
#     - use these pre determined moves for T
#         - a = UL ( 2,-1) ( 2,-2) ( 1,-2)
#         - b = _L ( 0, -2)
#         - c = DL (-2,-1) (-2,-2) (-1,-2)
#         - d = D_ (-2, 0)
#         - e = DR (-2, 1) (-2, 2) (-1, 2)
#         - f = _R ( 0, 2)
#         - g = UR ( 2, 1) ( 2, 2) ( 1, 2)
#         - h = U_ ( 2, 0)
#
# - may be helpful to keep an absolute coord of T for recording (to a set), and a relative coord on H from T
#     - start point can be arbitrarily set to (0,0)

# %%
# coordinate as (row, col)
left  = ( 0,-1)
right = ( 0, 1)
up    = ( 1, 0)
down  = (-1, 0)

def move(x,y): return (x[0] + y[0], x[1] + y[1])
def react(h, t, history):
    hr, hc = h
    if hr > 0 : 
        t = move(t,up)
        h = move(h,down)
        history.add(t)
    if hr < 0 :
        t = move(t,down)
        h = move(h,up)
        history.add(t)
    if hc > 0 : 
        t = move(t,right)
        h = move(h,left)
        history.add(t)
    if hr < 0 :
        t = move(t,left)
        h = move(h,right)
        history.add(t)
    return (h,t,history)

assert react((2,0),(0,0),set()) == ((1,0),(1,0),{(1,0)}), 'up 2'
assert react((0,2),(0,0),set()) == ((0,1),(0,1),{(0,1)}), 'right 2'
assert react((-2,0),(0,0),set()) == ((1,0),(1,0),{(1,0)}), 'down 2'
#assert react((0,-2),(0,0),set()) == ((1,0),(1,0),{(1,0)}), 'left 2'
